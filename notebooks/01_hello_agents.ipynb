# %% [markdown]
# # 🧪 Zoheb LLM Agent Toolkit - Lab Notebook Demonstration
#
# This interactive notebook demonstrates running scenarios directly inside a lab Virtual Machine (VM).
#
# > **Safety Notice:** Always run agent execution inside isolated sandbox/VM lab environments.

# %%
import sys
from pathlib import Path

# Ensure workspace directory is in python path
sys.path.append(str(Path.cwd().parent))

from scenarios import registry
from core.agent import BaseAgent
from agents.security_agents import create_security_analyst

# %% [markdown]
# ## 1. List Available Lab Scenarios

# %%
scenarios = registry.get_all()
for name, details in scenarios.items():
    print(f"Scenario: {name:<15} | Description: {details['description']}")

# %% [markdown]
# ## 2. Execute 'hello_agents' Scenario

# %%
registry.run_scenario('hello_agents')
